# %%
# # imports

# import numpy as np
# import os, glob
# import pandas as pd
# import numpy as np
# from sklearn.utils import shuffle
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.model_selection import train_test_split
# import tensorflow as tf
# #

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import random
from PIL import Image
# %matplotlib inline

# %%
img_folder = 'train/diced/'

plt.figure(figsize=(20,20))
for i in range(5):
    file = random.choice(os.listdir(img_folder))
    image_path= os.path.join(img_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
# creating the dataset

# normalize,with tensorflow 
# tf.img std
# ideal size of images
IMG_WIDTH=224
IMG_HEIGHT=224
img_folder = 'train/'


def create_dataset(img_folder):
    
    img_data_array=[]
    class_name=[]
    for dir1 in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):
       
            image_path= os.path.join(img_folder, dir1,  file)
            image= np.array(Image.open(image_path))
            image= np.resize(image,(IMG_HEIGHT,IMG_WIDTH,3))
            image = image.astype('float32')
            image /= 255  
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array , class_name

# extract the image array and class name
PIL_img_data, class_name=create_dataset(img_folder)

target_dict={k: v for v, k in enumerate(np.unique(class_name))}

print(target_dict, len(PIL_img_data))
# Out:
# {'creamy_paste': 0, 'diced': 1, 'floured': 2, 'grated': 3, 'juiced': 4, 'jullienne': 5, 'mixed': 6, 'other': 7, 'peeled': 8, 'sliced': 9, 'whole': 10} 198

# %%
target_dict= {k: v for v, k in enumerate(np.unique(class_name))}
target_val=  [target_dict[class_name[i]] for i in range(len(class_name))]
print(len(target_val))
# Out:
# 198

# %%
model=tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)),
            tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=(2, 2), activation='relu'),
            tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=(2, 2), activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(6)
        ])
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x=np.array(PIL_img_data, np.float32), y=np.array(list(map(int,target_val)), np.float32), epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[17], line 11
#       1 model=tf.keras.Sequential(
#       2         [
#       3             tf.keras.layers.InputLayer(input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)),
#    (...)
#       7             tf.keras.layers.Dense(6)
#       8         ])
#       9 model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 11 history = model.fit(x=np.array(PIL_img_data, np.float32), y=np.array(list(map(int,target_val)), np.float32), epochs=5)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "C:\Users\Ciner\anaconda3\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Ciner\anaconda3\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\base_events.py", line 1906, in _run_once
#       handle._run()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Ciner\AppData\Local\Temp\ipykernel_20912\3400563838.py", line 11, in <module>
#       history = model.fit(x=np.array(PIL_img_data, np.float32), y=np.array(list(map(int,target_val)), np.float32), epochs=5)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1024, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1082, in compute_loss
#       return self.compiled_loss(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 284, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 2098, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\backend.py", line 5633, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of 10 which is outside the valid range of [0, 6).  Label values: 5 10 0 3 0 7 9 9 5 9 8 8 4 9 6 4 10 7 2 8 6 9 2 0 9 4 2 1 5 5 5 7
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_2787]

# %%
# model=tf.keras.Sequential(
#         [
#             tf.keras.layers.InputLayer(input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)),
#             tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=(2, 2), activation='relu'),
#             tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=(2, 2), activation='relu'),
#             tf.keras.layers.Flatten(),
#             tf.keras.layers.Dense(6)
#         ])
# model.compile(optimizer='rmsprop', 
#               loss='sparse_categorical_crossentropy', 
#               metrics=['accuracy'])

# history = model.fit(
#     x=tf.cast(np.array(PIL_img_data), tf.float64), 
#     y=tf.cast(list(map(int,target_val)),
#               tf.int32), 
    epochs=5)
# history = model.fit(
#     x=np.array(PIL_img_data, np.float32), 
#     y=np.array(list(map(int,target_val)), 
#     np.float32), 
#     epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[14], line 13
#       1 model=tf.keras.Sequential(
#       2         [
#       3             tf.keras.layers.InputLayer(input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)),
#    (...)
#       7             tf.keras.layers.Dense(6)
#       8         ])
#       9 model.compile(optimizer='rmsprop',
#      10               loss='sparse_categorical_crossentropy',
#      11               metrics=['accuracy'])
# ---> 13 history = model.fit(
#      14     x=tf.cast(np.array(PIL_img_data), tf.float64),
#      15     y=tf.cast(list(map(int,target_val)),
#      16               tf.int32),
#      17     epochs=5)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "C:\Users\Ciner\anaconda3\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Ciner\anaconda3\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\base_events.py", line 1906, in _run_once
#       handle._run()
#     File "C:\Users\Ciner\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Ciner\AppData\Local\Temp\ipykernel_20912\2354289838.py", line 13, in <module>
#       history = model.fit(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1024, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\training.py", line 1082, in compute_loss
#       return self.compiled_loss(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 152, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 284, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\losses.py", line 2098, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "C:\Users\Ciner\anaconda3\lib\site-packages\keras\backend.py", line 5633, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of 10 which is outside the valid range of [0, 6).  Label values: 5 5 0 4 7 10 2 3 2 6 7 9 6 2 7 2 0 7 9 3 8 10 4 5 5 5 10 1 7 9 5 4
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_1798]
